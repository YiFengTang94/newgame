# %%
print 'hello'
# Out:
#   File "<ipython-input-1-bfbe230352b8>", line 1
#     print 'hello'
#                 ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
import graphviz

# %%
import graphviz

# %%
import sklearn.datasets as datasets
import pandas as pd
iris = datasets.load_iris()
df = pd.DataFrame(iris.data,columns = iris.feature_names)
y = iris.target

# %% [raw]
# from sklearn.tree import DecisionTreeClassfier
# dtree=DecisionTreeClassfier()
# dtree.fit(df,y)
# from sklearn.externals.six import StringIO
# from IPython.display import Image
# from sklearn.tree import export_graphviz
# import pydotplus
# dot_data = StringIO()
# export_graphviz(dtree,out_file=dot_data,
#                 filled = True,rounded = True,
#                 specialchracters = True)
# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# Image(graph.create_png())

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-5eb247d13b3c> in <module>()
#       4 import pydotplus
#       5 dot_data = StringIO()
# ----> 6 export_graphviz(dtree,out_file=dot_data,
#       7                 filled = True,rounded = True,
#       8                 specialchracters = True)
#
# NameError: name 'dtree' is not defined

# %%
import graphviz
import sklearn.datasets as datasets
import pandas as pd
iris = datasets.load_iris()
df = pd.DataFrame(iris.data,columns = iris.feature_names)
y = iris.target

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(df,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(dtree,out_file=dot_data,
                filled = True,rounded = True,
                special_chracters = True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-c27c9a92e141> in <module>()
#       6 export_graphviz(dtree,out_file=dot_data,
#       7                 filled = True,rounded = True,
# ----> 8                 special_chracters = True)
#       9 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
#      10 Image(graph.create_png())
#
# TypeError: export_graphviz() got an unexpected keyword argument 'special_chracters'

# %%
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(dtree,out_file=dot_data,
                filled = True,rounded = True,
                special_characters = True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
import numpy as np
A = np.array([1,2,3])
B = np.array([3,2,1])

print(np.add(A,B))
print(np.subtract(A,B))
# Out:
# [4 4 4]
# [-2  0  2]

# %%
np.multiply(A,A)
# Out:
# array([1, 4, 9])

# %%
A*A
# Out:
# array([1, 4, 9])

# %%
C = np.array([[1,1],
              [2,2],
              [3,3]])
A@C
# Out:
# array([14, 14])
